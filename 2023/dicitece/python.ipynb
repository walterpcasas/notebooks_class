# %%
print('hola mundo')
# Out:
# hola mundo

# %%
var1 = 23
var2 = 4.5

print(var1 + var2)
# Out:
# 27.5

# %%
nombre = 'Wilton'

print(nombre)
# Out:
# Wilton

# %%
print(3 * nombre)
# Out:
# WiltonWiltonWilton

# %%
print(3 + nombre)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7b32d4ae6965> in <cell line: 1>()
# ----> 1 print(3 + nombre)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
apellido = 'Camacho'

# %%
print(nombre, apellido)
# Out:
# Wilton Camacho

# %%
def suma(num1, num2):
  resultado = num1 + num2
  return resultado

# %%
suma(5, 6)
# Out:
# 11

# %%
print(suma(9, 7))
print(suma(9, 17))
print(suma(29, 37))
print(suma(12, 57))
# Out:
# 16
# 26
# 66
# 69

# %%
print(suma(9, 7) + suma(9, 17))
# Out:
# 42

# %%
edades = [25, 13, 76, 18]

# %%
for edad in edades:
  print('El alumno tiene:', edad)
# Out:
# El alumno tiene: 25
# El alumno tiene: 13
# El alumno tiene: 76
# El alumno tiene: 18

# %%
for edad in edades:
  if edad >= 18:
    print('El alumno tiene:', edad)
    print('Es mayor de edad')
# Out:
# El alumno tiene: 25
# Es mayor de edad
# El alumno tiene: 76
# Es mayor de edad
# El alumno tiene: 18
# Es mayor de edad
