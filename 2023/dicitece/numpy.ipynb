# %%
notas1 = [12, 7, 10, 11]
notas2 = [15, 14, 17, 13]

# %%
type(notas1)
# Out:
# list

# %%
suma = []

# len(notas1) = 4
# range(4) = [0, 1, 2, 3]
for i in range(len(notas1)):
  suma.append(notas1[i] + notas2[i])

print(suma)
# Out:
# [27, 21, 27, 24]

# %% [markdown]
# # Con Numpy

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# %%
notas3 = np.array([12, 7, 10, 11])
notas4 = np.array([15, 14, 17, 13])

# %%
type(notas3)
# Out:
# numpy.ndarray

# %%
notas3 + notas4
# Out:
# array([27, 21, 27, 24])

# %%
print(np.__version__)
# Out:
# 1.22.4

# %% [markdown]
# ## Dimensiones

# %%
arreglo = np.array([3, 5, 7])
print(arreglo)
# Out:
# [3 5 7]

# %%
arreglo.ndim
# Out:
# 1

# %%
arreglo2d = np.array([[2, 4], [3, 5]])
print(arreglo2d)
print(type(arreglo2d))
# Out:
# [[2 4]
#  [3 5]]
# <class 'numpy.ndarray'>

# %%
test = [[2, 4], [3, 5]]
print(test)
print(type(test))
# Out:
# [[2, 4], [3, 5]]
# <class 'list'>

# %%
arreglo2d.ndim
# Out:
# 2

# %%
arreglo3d = np.array([[[2, 4], [3, 5]], [[6, 8], [7, 9]]])
print(arreglo3d)
# Out:
# [[[2 4]
#   [3 5]]
#
#  [[6 8]
#   [7 9]]]

# %%
arreglo3d.ndim
# Out:
# 3

# %%
arreglo2d = np.array([[2, 4], [3, 5]])
print(arreglo2d)
# Out:
# [[2 4]
#  [3 5]]

# %%
arreglo2e = np.array([[1, 3], [2, 4]])
print(arreglo2e)
# Out:
# [[1 3]
#  [2 4]]

# %%
sumaMatrices = arreglo2d + arreglo2e
print(sumaMatrices)
# Out:
# [[3 7]
#  [5 9]]

# %%
print(type(sumaMatrices))
# Out:
# <class 'numpy.ndarray'>

# %%
sumaMatrices.ndim
# Out:
# 2

# %% [markdown]
# ## Accediendo a datos

# %%
arreglo = np.array([3, 5, 7, 9, 1, 12, 15])
print(arreglo)
# Out:
# [ 3  5  7  9  1 12 15]

# %%
arreglo[1]
# Out:
# 5

# %%
arreglo[5]
# Out:
# 12

# %%
arreglo[-2]
# Out:
# 12

# %%
arreglo[-3]
# Out:
# 1

# %%
# slicing
arreglo[1:4]
# Out:
# array([5, 7, 9])

# %%
#[ 3  5  7  9  1 12 15]
arreglo[2:6]
# Out:
# array([ 7,  9,  1, 12])

# %%
arreglo[2:-1]
# Out:
# array([ 7,  9,  1, 12])

# %%
arreglo[:-1]
# Out:
# array([ 3,  5,  7,  9,  1, 12])

# %%
arreglo[1:]
# Out:
# array([ 5,  7,  9,  1, 12, 15])

# %%
arreglo2d = np.array([[2, 4], [3, 5]])
print(arreglo2d)
# Out:
# [[2 4]
#  [3 5]]

# %%
arreglo2d[0]
# Out:
# array([2, 4])

# %%
arreglo2d[0][1]
# Out:
# 4

# %%
arreglo2d[1]
# Out:
# array([3, 5])

# %%
arreglo2d[1][0]
# Out:
# 3

# %%
arregloX = np.array([[2, 4, 6, 8], [3, 5, 7, 9]])
print(arregloX)
# Out:
# [[2 4 6 8]
#  [3 5 7 9]]

# %%
arregloX[1]
# Out:
# array([3, 5, 7, 9])

# %%
arregloX[1][2:]
# Out:
# array([7, 9])

# %%
arregloX.ndim
# Out:
# 2

# %%
arregloX.shape
# Out:
# (2, 4)

# %%
arreglo2d.shape
# Out:
# (2, 2)

# %%
arreglo
# Out:
# array([ 3,  5,  7,  9,  1, 12, 15])

# %%
arreglo.ndim
# Out:
# 1

# %%
arreglo.shape
# Out:
# (7,)

# %%
arreglo = np.array([3, 5, 7, 9, 1, 12, 15, 99])
print(arreglo)
# Out:
# [ 3  5  7  9  1 12 15 99]

# %%
arreglo.shape
# Out:
# (8,)

# %%
arreglo.reshape(2, 4)
# Out:
# array([[ 3,  5,  7,  9],
#        [ 1, 12, 15, 99]])

# %%
arreglo.reshape(4, 2)
# Out:
# array([[ 3,  5],
#        [ 7,  9],
#        [ 1, 12],
#        [15, 99]])

# %%
arreglo.reshape(2, -1)
# Out:
# array([[ 3,  5,  7,  9],
#        [ 1, 12, 15, 99]])

# %%
arreglo.reshape(3, -1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-0effb6d2f20a> in <cell line: 1>()
# ----> 1 arreglo.reshape(3, -1)
#
# ValueError: cannot reshape array of size 8 into shape (3,newaxis)

# %%
arreglo
# Out:
# array([ 3,  5,  7,  9,  1, 12, 15, 99])

# %%
arreglo.shape
# Out:
# (8,)

# %%
tmp = arreglo.reshape(-1, 1)
tmp
# Out:
# array([[ 3],
#        [ 5],
#        [ 7],
#        [ 9],
#        [ 1],
#        [12],
#        [15],
#        [99]])

# %%
tmp.shape
# Out:
# (8, 1)

# %%
arreglo.reshape(1, -1)
# Out:
# array([[ 3,  5,  7,  9,  1, 12, 15, 99]])

# %%
arr1 = np.array([1, 3, 5])
arr2 = np.array([2, 4, 6])

# %%
arr1
# Out:
# array([1, 3, 5])

# %%
arr2
# Out:
# array([2, 4, 6])

# %%
arrRes = np.concatenate((arr1, arr2))
arrRes
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
type(arrRes)
# Out:
# numpy.ndarray

# %%
arrRes.shape
# Out:
# (6,)

# %%
arrRes = np.concatenate((arr1, arr2))
arrRes
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
np.hstack((arr1, arr2))
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
np.vstack((arr1, arr2))
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
arrRes
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
np.where(arrRes > 3)
# Out:
# (array([2, 4, 5]),)

# %%
out = np.where(arrRes%2 == 0)
out
# Out:
# (array([3, 4, 5]),)

# %%
for i in out[0]:
  print(arrRes[i])
# Out:
# 2
# 4
# 6

# %%
for i in np.where(arrRes%2 == 0)[0]:
  print(arrRes[i])
# Out:
# 2
# 4
# 6

# %%
np.sort(arrRes)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arrRes
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
arrRes > 2
# Out:
# array([False,  True,  True, False,  True,  True])

# %%
arrRes[arrRes > 2]
# Out:
# array([3, 5, 4, 6])

# %%
arrRes[arrRes%2 != 0]
# Out:
# array([1, 3, 5])

# %%
arrRes[arrRes%4 != 0]
# Out:
# array([1, 3, 5, 2, 6])
