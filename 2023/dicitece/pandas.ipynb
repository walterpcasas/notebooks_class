# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
# !pip install pandas==2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 54.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.0
#     Uninstalling pandas-1.3.0:
#       Successfully uninstalled pandas-1.3.0
# ...

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.0'

# %%
notas = {"Maria": [14, 16, 12, 18],
         "Hugo": [17, 6, 10, 15],
         "Cesar": [12, 11, 12, 13]}

# %%
notas
# Out:
# {'Maria': [14, 16, 12, 18], 'Hugo': [17, 6, 10, 15], 'Cesar': [12, 11, 12, 13]}

# %%
df = pd.DataFrame(notas)

# %%
df
# Out:
#    Maria  Hugo  Cesar
# 0     14    17     12
# 1     16     6     11
# 2     12    10     12
# 3     18    15     13

# %%
df = pd.DataFrame(notas, index=['Matematicas', 'Biologia', 'Literatura', 'Filosofia'])

# %%
df
# Out:
#              Maria  Hugo  Cesar
# Matematicas     14    17     12
# Biologia        16     6     11
# Literatura      12    10     12
# Filosofia       18    15     13

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.mean()
# Out:
# Maria    15.0
# Hugo     12.0
# Cesar    12.0
# dtype: float64

# %%
df.median()
# Out:
# Maria    15.0
# Hugo     12.5
# Cesar    12.0
# dtype: float64

# %%
type(df.mean())
# Out:
# pandas.core.series.Series

# %%
df['Maria']
# Out:
# Matematicas    14
# Biologia       16
# Literatura     12
# Filosofia      18
# Name: Maria, dtype: int64

# %%
df["Hugo"]
# Out:
# Matematicas    17
# Biologia        6
# Literatura     10
# Filosofia      15
# Name: Hugo, dtype: int64

# %%
type(df["Hugo"])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#              Maria  Hugo  Cesar
# Matematicas     14    17     12
# Biologia        16     6     11
# Literatura      12    10     12
# Filosofia       18    15     13

# %%
df.sum()
# Out:
# Maria    60
# Hugo     48
# Cesar    48
# dtype: int64

# %%
series = pd.Series([1, 2, 3])
series
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
series = pd.Series([1, 2., 3])
series
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
series = pd.Series([1, 2., 3, 'texto'])
series
# Out:
# 0        1
# 1      2.0
# 2        3
# 3    texto
# dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series = pd.Series([1, 2., 3, 0, np.nan])
series
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# 4    NaN
# dtype: float64

# %%
series[2] + series[0]
# Out:
# 4.0

# %%
series = pd.Series([1, 2., 3, 'texto'])
series
# Out:
# 0        1
# 1      2.0
# 2        3
# 3    texto
# dtype: object

# %%
type(series[1])
# Out:
# float

# %%
type(series[3])
# Out:
# str

# %%
type(series[0])
# Out:
# int

# %%
series = pd.Series([1, 2., 3, 'texto', np.nan, 0, False, '', 1231, .0])
series
# Out:
# 0        1
# 1      2.0
# 2        3
# 3    texto
# 4      NaN
# 5        0
# 6    False
# 7
# 8     1231
# 9      0.0
# dtype: object

# %%
type(series[4])
# Out:
# float

# %%
series[4]
# Out:
# nan

# %%
type(series[7])
# Out:
# str

# %%
series[7]
# Out:
# ''

# %%
len(series[7])
# Out:
# 0

# %%
notas = {"Maria": [14, 16, 12, 18],
         "Hugo": [17, 6, 10, 15],
         "Cesar": [12, 11, 12, 13],
         "Piero": [11, 16, np.nan, 14]}

# %%
df = pd.DataFrame(notas)

# %%
df
# Out:
#    Maria  Hugo  Cesar  Piero
# 0     14    17     12   11.0
# 1     16     6     11   16.0
# 2     12    10     12    NaN
# 3     18    15     13   14.0

# %%
df.mean()
# Out:
# Maria    15.000000
# Hugo     12.000000
# Cesar    12.000000
# Piero    13.666667
# dtype: float64

# %%
df.median()
# Out:
# Maria    15.0
# Hugo     12.5
# Cesar    12.0
# Piero    14.0
# dtype: float64

# %%
df.describe()
# Out:
#            Maria       Hugo      Cesar      Piero
# count   4.000000   4.000000   4.000000   3.000000
# mean   15.000000  12.000000  12.000000  13.666667
# std     2.581989   4.966555   0.816497   2.516611
# min    12.000000   6.000000  11.000000  11.000000
# 25%    13.500000   9.000000  11.750000  12.500000
# 50%    15.000000  12.500000  12.000000  14.000000
# 75%    16.500000  15.500000  12.250000  15.000000
# max    18.000000  17.000000  13.000000  16.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Maria   4 non-null      int64
#  1   Hugo    4 non-null      int64
#  2   Cesar   4 non-null      int64
#  3   Piero   3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 256.0 bytes

# %%
df
# Out:
#    Maria  Hugo  Cesar  Piero
# 0     14    17     12   11.0
# 1     16     6     11   16.0
# 2     12    10     12    NaN
# 3     18    15     13   14.0

# %%
df.fillna(5)
# Out:
#    Maria  Hugo  Cesar  Piero
# 0     14    17     12   11.0
# 1     16     6     11   16.0
# 2     12    10     12    5.0
# 3     18    15     13   14.0

# %%
df.fillna(5, inplace=True)

# %%
df
# Out:
#    Maria  Hugo  Cesar  Piero
# 0     14    17     12   11.0
# 1     16     6     11   16.0
# 2     12    10     12    5.0
# 3     18    15     13   14.0

# %%
df['Cesar']
# Out:
# 0    12
# 1    11
# 2    12
# 3    13
# Name: Cesar, dtype: int64

# %%
df.Cesar
# Out:
# 0    12
# 1    11
# 2    12
# 3    13
# Name: Cesar, dtype: int64

# %%
df[df.Hugo > 10]
# Out:
#    Maria  Hugo  Cesar  Piero
# 0     14    17     12   11.0
# 3     18    15     13   14.0

# %%
df[df.Hugo > 10]['Hugo']
# Out:
# 0    17
# 3    15
# Name: Hugo, dtype: int64

# %%
df[df.Hugo > 10][['Hugo']]
# Out:
#    Hugo
# 0    17
# 3    15
